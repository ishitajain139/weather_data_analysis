# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('weather.csv')

# %%
df2=df.dropna()
df2[['SUBDIVISION','YEAR','ANNUAL']]
# Out:
#                     SUBDIVISION  YEAR  ANNUAL
# 0     Andaman & Nicobar Islands  1901  3373.2
# 1     Andaman & Nicobar Islands  1902  3520.7
# 2     Andaman & Nicobar Islands  1903  2957.4
# 3     Andaman & Nicobar Islands  1904  3079.6
# 4     Andaman & Nicobar Islands  1905  2566.7
# ...                         ...   ...     ...
# 4183                Lakshadweep  2013  1426.3
# 4184                Lakshadweep  2014  1395.0
# 4185                Lakshadweep  2015  1642.9
# 4186                Lakshadweep  2016  1065.7
# 4187                Lakshadweep  2017  1738.9
#
# [4162 rows x 3 columns]

# %%
state1=input("state1= ")
state2=input("state2= ")
sub=df2['SUBDIVISION']
state1=df2.loc[sub==state1,:]
state2=df2.loc[sub==state2,:]


frames=[state1,state2]
dfn=pd.concat(frames)
dfn
# Out:
# state1= Orissa
# state2= Bihar
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY    JUN    JUL    AUG  \
# 679       Orissa  1901  39.5  65.1  16.1   51.6   79.0   78.2  288.4  307.7
# 680       Orissa  1902   3.4   0.2  14.2  101.1   56.7  108.3  437.4  349.1
# 681       Orissa  1903  19.7  18.9  10.5   34.6   73.3  154.3  410.4  295.2
# 682       Orissa  1904   0.2  12.2  20.6   10.1  100.2  342.9  336.7  350.4
# 683       Orissa  1905  24.3  17.2  66.3   56.9  107.5   92.0  330.1  281.4
# ...          ...   ...   ...   ...   ...    ...    ...    ...    ...    ...
# 1025       Bihar  2013   5.1  22.6   0.6   32.3   89.5  183.3  182.0  213.6
# 1026       Bihar  2014  17.0  33.5   8.4    0.7  103.9  115.2  265.4  307.6
# 1027       Bihar  2015  12.8   1.8  27.2   38.7   39.5  122.1  231.5  287.0
# 1028       Bihar  2016   9.3   0.6   5.6    3.9   84.0  128.7  356.4  150.8
# 1029       Bihar  2017   0.7   0.0  22.8   21.8   79.7   84.6  379.9  342.8
#
# ...

# %%
dfn = dfn.sort_values(by=['YEAR','ANNUAL'])
dfn[['SUBDIVISION','YEAR','ANNUAL']]
dfn
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR   MAY    JUN    JUL    AUG  \
# 913        Bihar  1901  51.8  19.6  11.9    1.1  65.6   66.3  245.9  319.4
# 679       Orissa  1901  39.5  65.1  16.1   51.6  79.0   78.2  288.4  307.7
# 914        Bihar  1902   4.6   0.7  24.3   17.3  66.3  118.2  361.0  225.5
# 680       Orissa  1902   3.4   0.2  14.2  101.1  56.7  108.3  437.4  349.1
# 915        Bihar  1903   5.3   4.7   2.0    4.7  28.2  192.9  115.0  342.6
# ...          ...   ...   ...   ...   ...    ...   ...    ...    ...    ...
# 793       Orissa  2015  15.1   3.3  10.5   67.6  32.6  238.6  294.8  264.0
# 1028       Bihar  2016   9.3   0.6   5.6    3.9  84.0  128.7  356.4  150.8
# 794       Orissa  2016   2.2  16.7  15.2    8.6  74.9  164.2  280.3  320.8
# 1029       Bihar  2017   0.7   0.0  22.8   21.8  79.7   84.6  379.9  342.8
# 795       Orissa  2017   1.7   0.0  29.8    8.7  55.2  209.5  349.7  301.7
#
#         SEP    OCT   NOV   DEC  ANNUAL
# ...

# %%
year=int(input("year= "))
st=dfn['YEAR']
statedf=dfn.loc[Orissa['ANNUAL']>Bihar['ANNUAL'],:]
statedf
# Out:
# year= 1906
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-5ed1c697f1a8> in <module>
#       1 year=int(input("year= "))
#       2 st=dfn['YEAR']
# ----> 3 statedf=dfn.loc[Orissa['ANNUAL']>Bihar['ANNUAL'],:]
#       4 statedf
#
# NameError: name 'Orissa' is not defined

# %%
groupobj = df2.groupby('SUBDIVISION')
data1 = groupobj.get_group(state1)

groupobj = df2.groupby('SUBDIVISION')
data2 = groupobj.get_group(state2)

frames=[data1,data2]
df4=pd.concat(frames)
df4
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY    JUN    JUL    AUG  \
# 679       Orissa  1901  39.5  65.1  16.1   51.6   79.0   78.2  288.4  307.7
# 680       Orissa  1902   3.4   0.2  14.2  101.1   56.7  108.3  437.4  349.1
# 681       Orissa  1903  19.7  18.9  10.5   34.6   73.3  154.3  410.4  295.2
# 682       Orissa  1904   0.2  12.2  20.6   10.1  100.2  342.9  336.7  350.4
# 683       Orissa  1905  24.3  17.2  66.3   56.9  107.5   92.0  330.1  281.4
# ...          ...   ...   ...   ...   ...    ...    ...    ...    ...    ...
# 1025       Bihar  2013   5.1  22.6   0.6   32.3   89.5  183.3  182.0  213.6
# 1026       Bihar  2014  17.0  33.5   8.4    0.7  103.9  115.2  265.4  307.6
# 1027       Bihar  2015  12.8   1.8  27.2   38.7   39.5  122.1  231.5  287.0
# 1028       Bihar  2016   9.3   0.6   5.6    3.9   84.0  128.7  356.4  150.8
# 1029       Bihar  2017   0.7   0.0  22.8   21.8   79.7   84.6  379.9  342.8
#
#         SEP    OCT   NOV   DEC  ANNUAL
# ...

# %%
dt=df4.loc

# %%
groupobj = df4.groupby('YEAR')
data = groupobj['ANNUAL'].agg([np.max])
data
# Out:
#         amax
# YEAR
# 1901  1284.2
# 1902  1349.0
# 1903  1568.3
# 1904  1514.8
# 1905  1498.5
# ...      ...
# 2013  1632.4
# 2014  1536.9
# 2015  1210.1
# 2016  1253.5
# 2017  1344.5
#
# [117 rows x 1 columns]
