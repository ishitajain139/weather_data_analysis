# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('weather.csv')

# %%
df2=df.dropna()
df2
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     Andaman & Nicobar Islands  1901  49.2   87.1   29.2    2.3  528.8
# 1     Andaman & Nicobar Islands  1902   0.0  159.8   12.2    0.0  446.1
# 2     Andaman & Nicobar Islands  1903  12.7  144.0    0.0    1.0  235.1
# 3     Andaman & Nicobar Islands  1904   9.4   14.7    0.0  202.4  304.5
# 4     Andaman & Nicobar Islands  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4183                Lakshadweep  2013  26.2   34.4   37.5    5.3   88.3
# 4184                Lakshadweep  2014  53.2   16.1    4.4   14.9   57.4
# 4185                Lakshadweep  2015   2.2    0.5    3.7   87.1  133.1
# 4186                Lakshadweep  2016  59.6   12.1    3.2    2.6   77.4
# 4187                Lakshadweep  2017  21.3    0.9  100.2    1.8  145.7
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL
# ...

# %%
state1=input("state1= ")
yr=int(input("year= "))
# Out:
# state1= Orissa
# year= 1907

# %%
groupobj = df2.groupby('SUBDIVISION')
data = groupobj.get_group(state1)
groupobj = data.groupby('YEAR')
data = groupobj.get_group(yr)
data
# Out:
#     SUBDIVISION  YEAR  JAN   FEB   MAR    APR   MAY    JUN    JUL    AUG  \
# 685      Orissa  1907  0.1  16.9  57.4  105.1  39.8  226.3  203.9  531.8
#
#        SEP   OCT   NOV   DEC  ANNUAL
# 685  204.8  15.9  14.0  31.2  1447.1

# %%
data['ANNUAL']
# Out:
# 685    1447.1
# Name: ANNUAL, dtype: float64

# %%
df3 = df2.loc[df2['ANNUAL']<1447.1,:]
df3
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 399   Naga Mani Mizo Tripura  1972   4.5   46.3  32.8  145.0  169.1  235.6
# 563     Gangetic West Bengal  1902   0.0    1.2  44.2  103.8  161.6  140.9
# 564     Gangetic West Bengal  1903  17.5   24.6  37.3   30.6   78.5  201.7
# 565     Gangetic West Bengal  1904   0.1   23.9  35.6   17.5  160.2  286.7
# 567     Gangetic West Bengal  1906  46.8  123.6  53.3    1.1   81.3  172.0
# ...                      ...   ...   ...    ...   ...    ...    ...    ...
# 4172             Lakshadweep  2002  10.8   16.8   7.2   23.4  189.8  261.8
# 4182             Lakshadweep  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4183             Lakshadweep  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4184             Lakshadweep  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4186             Lakshadweep  2016  59.6   12.1   3.2    2.6   77.4  321.1
#
#         JUL    AUG    SEP    OCT   NOV   DEC  ANNUAL
# ...
